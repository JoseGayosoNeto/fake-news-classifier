# %% [markdown]
# # **Carregar dados dos datasets de notícias falsas e verdadeiras**

# %% [markdown]
# ### Adiciona o caminho de src para permitir importações deste diretório

# %%
import os
import sys
from pathlib import Path

# Define o caminho base do projeto (um nível acima de /notebooks)
BASE_DIR = Path(__file__).resolve().parent.parent  if '__file__' in globals() else Path.cwd().parent

# Caminho para a pasta src/
SRC_DIR = BASE_DIR / "src"

# Adiciona SRC_DIR e BASE_DIR ao sys.path
sys.path.append(str(BASE_DIR))
sys.path.append(str(SRC_DIR))

# %% [markdown]
# ### Importação dos datasets

# %%
from src.data_loader import load_dataset


# Caminhos dos datasets. É necessário que os arquivos dos datasets estejam na pasta data/raw/
# Se não estiverem, você deve criar a pasta e colocar os arquivos Fake.csv e True.csv lá.
if not os.path.exists(os.path.join(BASE_DIR, "data", "raw")):
    os.makedirs(os.path.join(BASE_DIR, "data", "raw"), exist_ok=True)
fake_dataset_path = os.path.join(BASE_DIR, "data", "raw", "Fake.csv")
real_dataset_path = os.path.join(BASE_DIR, "data", "raw", "True.csv")

fake_dataset, real_dataset, concat_dataset = load_dataset(fake_dataset_path, real_dataset_path)

# %% [markdown]
# ### Exemplos de saídas de amostras dos datasets

# %%
print("Fake Dataset:")
print("Formato: ", fake_dataset.shape)
fake_dataset.sample(5)
# Out:
# Fake Dataset:
# Formato:  (23481, 5)
#                                                    title  \
# 17668  WATCH: ARROGANT Sexual Predator and Sometimes ...
# 13524  DAY AFTER DALLAS COPS’ MEMORIAL, Obama Invites...
# 2516    WATCH: Morning Joe Host Tells Kellyanne Conwa...
# 223     Hustler Owner Is So Fed Up With Trump That He...
# 16060  BREAKING: President Trump Makes FBI Pick One D...
#
#                                                     text          subject  \
# 17668  The not so funny comedian Louis C.K. appeared ...        left-news
# 13524  When America elected a Community Agitator, the...         politics
# 2516   Kellyanne Conway is definitely going to whine ...             News
# 223    Donald Trump is a danger to the nation and the...             News
# 16060  President Trump has nominated Christopher Wray...  Government News
#
#                     date  label
# 17668        Nov 9, 2017      0
# 13524       Jul 13, 2016      0
# 2516   February 15, 2017      0
# 223     October 14, 2017      0
# 16060        Jun 7, 2017      0

# %%
print("Real Dataset:")
print("Formato: ", real_dataset.shape)
real_dataset.sample(5)
# Out:
# Real Dataset:
# Formato:  (21417, 5)
#                                                    title  \
# 15691  Thousands march against coal ahead of climate ...
# 3269   About 19.5 million U.S. viewers watched Comey ...
# 15950  German railway under fire for proposal to name...
# 5901   Dozens barred from flying out of Istanbul airp...
# 603    U.S. Interior Secretary fails to provide paper...
#
#                                                     text       subject  \
# 15691  FRANKFURT (Reuters) - Thousands of people took...     worldnews
# 3269   (Reuters) - Former FBI Director James Comey’s ...  politicsNews
# 15950  BERLIN (Reuters) - German rail operator Deutsc...     worldnews
# 5901   ISTANBUL (Reuters) - Dozens of people were sto...  politicsNews
# 603    WASHINGTON (Reuters) - The U.S. Interior Depar...  politicsNews
#
#                      date  label
# 15691   November 4, 2017       1
# 3269        June 9, 2017       1
# 15950   November 1, 2017       1
# 5901    January 29, 2017       1
# 603    November 16, 2017       1

# %%
print("Dataset Concatenado:")
print("Formato: ", concat_dataset.shape)
concat_dataset.sample(5)
# Out:
# Dataset Concatenado:
# Formato:  (44898, 5)
#                                                    title  \
# 20630  CONSERVATIVE MOM And Cruz Supporter Goes All I...
# 3536    New Poll Shows Republicans Hilariously Abando...
# 27960  U.S. labor chief wants more drastic changes to...
# 30820  Pollsters who predicted Trump win benefit from...
# 1108    Christians Can Now Discriminate Against LGBT ...
#
#                                                     text       subject  \
# 20630  A message from a 100% FED UP mom to her Facebo...     left-news
# 3536   Republicans apparently have no idea what they ...          News
# 27960  WASHINGTON (Reuters) - Top U.S. labor leader R...  politicsNews
# 30820  NEW YORK (Reuters) - A handful of small public...  politicsNews
# 1108   It is now possible for religious adoption agen...          News
#
#                      date  label
# 20630         May 4, 2016      0
# 3536     December 6, 2016      0
# 27960      April 4, 2017       1
# 30820  November 11, 2016       1
# 1108        June 16, 2017      0

# %% [markdown]
# # **Pré-processamento do dataset concatenado**

# %%
from src.preprocessing import preprocess_dataframe


processed_df = preprocess_dataframe(concat_dataset)

print("Dataset Processado:")
print("Formato: ", processed_df.shape)
processed_df.sample(5)
# Out:
# Dataset Processado:
# Formato:  (44889, 7)
#                                                    title  \
# 2728    Democrats Launch Plan To Make Trump’s First S...
# 3363    Conservatives Demand Purge Of LGBT Employees ...
# 23069  Washington Post Deceives Public & Profits From...
# 18853  WHY DEMOCRATS Can Thank HARRY REID For Replaci...
# 33247  Valeant to pay new CEO Papa base salary of $1....
#
#                                                     text       subject  \
# 2728   Alleged president Donald Trump has literally m...          News
# 3363   Conservatives apparently want a witch hunt in ...          News
# 23069  21st Century Wire says The Washington Post has...   Middle-east
# 18853  In 2013, Senate Majority Leader Harry Reid use...     left-news
# 33247  (Reuters) - Drugmaker Valeant Pharmaceuticals ...  politicsNews
#
#                     date  label  \
# 2728    February 2, 2017      0
# 3363   December 18, 2016      0
# 23069    January 7, 2017      0
# 18853        Apr 7, 2017      0
# 33247    April 27, 2016       1
#
#                                                full_text  \
# 2728    Democrats Launch Plan To Make Trump’s First S...
# 3363    Conservatives Demand Purge Of LGBT Employees ...
# 23069  Washington Post Deceives Public & Profits From...
# 18853  WHY DEMOCRATS Can Thank HARRY REID For Replaci...
# 33247  Valeant to pay new CEO Papa base salary of $1....
#
#                                          full_text_clean
# 2728   democrat launch plan make trump first speech c...
# 3363   conservative demand purge lgbt employee state ...
# 23069  washington post deceives public profit fake ne...
# 18853  democrat thank harry reid replacing justice sc...
# 33247  valeant pay new ceo papa base salary million d...

# %% [markdown]
# # **Armazenamento do dataset concatenado processado**

# %%
# Salva o dataset processado em um arquivo CSV. É necessário que a pasta processed exista dentro de data.
if not os.path.exists(os.path.join(BASE_DIR, "data", "processed")):
    os.makedirs(os.path.join(BASE_DIR, "data", "processed"), exist_ok=True)
processed_df.to_csv(os.path.join(BASE_DIR, "data", "processed", "processed_dataset.csv"), index=False)
