# %% [markdown]
# # **Carregar dados dos datasets de notícias falsas e verdadeiras**

# %% [markdown]
# ### Adiciona o caminho de src para permitir importações deste diretório

# %%
import os
import sys
from pathlib import Path

# Define o caminho base do projeto (um nível acima de /notebooks)
BASE_DIR = Path(__file__).resolve().parent.parent  if '__file__' in globals() else Path.cwd().parent

# Caminho para a pasta src/
SRC_DIR = BASE_DIR / "src"

# Adiciona SRC_DIR e BASE_DIR ao sys.path
sys.path.append(str(BASE_DIR))
sys.path.append(str(SRC_DIR))

# %% [markdown]
# ### Importação dos datasets

# %%
from src.data_loader import load_dataset


# Caminhos dos datasets. É necessário que os arquivos dos datasets estejam na pasta data/raw/
# Se não estiverem, você deve criar a pasta e colocar os arquivos Fake.csv e True.csv lá.
if not os.path.exists(os.path.join(BASE_DIR, "data", "raw")):
    os.makedirs(os.path.join(BASE_DIR, "data", "raw"), exist_ok=True)
fake_dataset_path = os.path.join(BASE_DIR, "data", "raw", "Fake.csv")
real_dataset_path = os.path.join(BASE_DIR, "data", "raw", "True.csv")

fake_dataset, real_dataset, concat_dataset = load_dataset(fake_dataset_path, real_dataset_path)

# %% [markdown]
# ### Exemplos de saídas de amostras dos datasets

# %%
print("Fake Dataset:")
print("Formato: ", fake_dataset.shape)
fake_dataset.sample(5)
# Out:
# Fake Dataset:
# Formato:  (23481, 5)
#                                                    title  \
# 18947  BREAKING: STARBUCKS CEO To Step Down After Ple...
# 19220  “REVEREND” AL SHARPTON Makes Up Lie About Jesu...
# 22242  SUNDAY SCREENING: Counter Intelligence – ‘The ...
# 3209    This Compilation Of Alec Baldwin HUMILIATING ...
# 9372   WHAT TRUMP JUST SAID Should Scare All Gropers ...
#
#                                                     text    subject  \
# 18947  The arrogance of a CEO of a major company like...  left-news
# 19220  Hey Al you do realize that Obama was more than...  left-news
# 22242  21st Century Wire says Our weekly documentary ...    US_News
# 3209   Donald Trump threw a party to celebrate the Ne...       News
# 9372   President Trump wants those who settled sexual...   politics
#
#                     date  label
# 18947       Mar 19, 2017      0
# 19220       Jan 30, 2017      0
# 22242   January 29, 2017      0
# 3209   December 31, 2016      0
# 9372        Nov 21, 2017      0

# %%
print("Real Dataset:")
print("Formato: ", real_dataset.shape)
real_dataset.sample(5)
# Out:
# Real Dataset:
# Formato:  (21417, 5)
#                                                    title  \
# 1933   House speaker urges Trump not to scrap 'Dreame...
# 5343   EU's Tusk says agreed with U.S. Pence on need ...
# 20769  UK Brexit minister says 'good prospect' of agr...
# 13593  Britain close to deal on Brexit bill with EU -...
# 4645   Trump son-in-law met executives of sanctioned ...
#
#                                                     text       subject  \
# 1933   WASHINGTON (Reuters) - House of Representative...  politicsNews
# 5343   BRUSSELS (Reuters) - European Council Presiden...  politicsNews
# 20769  LONDON (Reuters) - There is a good prospect Br...     worldnews
# 13593  BRUSSELS/LONDON (Reuters) - Britain has offere...     worldnews
# 4645    MOSCOW/WASHINGTON (Reuters) - A Russian bank ...  politicsNews
#
#                      date  label
# 1933   September 1, 2017       1
# 5343   February 20, 2017       1
# 20769  September 7, 2017       1
# 13593  November 29, 2017       1
# 4645      March 27, 2017       1

# %%
print("Dataset Concatenado:")
print("Formato: ", concat_dataset.shape)
concat_dataset.sample(5)
# Out:
# Dataset Concatenado:
# Formato:  (44898, 5)
#                                                    title  \
# 16839  DID IRAN RELEASE This Footage Of Captured U.S....
# 19804  BEN CARSON DESTROYS Interrupting Anti-Trump MS...
# 40874  New Zealand likely to announce new government ...
# 59      While Honoring Native American Code Talkers, ...
# 24710  Republican Senator Collins likely 'yes' vote t...
#
#                                                     text          subject  \
# 16839  And what about the female sailor in the headsc...  Government News
# 19804  Notify the CDC. It's spreading. #BenCarson #Mo...        left-news
# 40874  WELLINGTON (Reuters) - New Zealand acting Prim...        worldnews
# 59     Former reality show star Donald Trump just can...             News
# 24710  WASHINGTON (Reuters) - U.S. Republican Senator...     politicsNews
#
#                     date  label
# 16839       Jan 14, 2016      0
# 19804       Oct 14, 2016      0
# 40874  October 15, 2017       1
# 59     November 27, 2017      0
# 24710  October 15, 2017       1

# %% [markdown]
# # **Pré-processamento do dataset concatenado**

# %%
from src.preprocessing import preprocess_dataframe


processed_df = preprocess_dataframe(concat_dataset)

print("Dataset Processado:")
print("Formato: ", processed_df.shape)
processed_df.sample(5)
# Out:
# Dataset Processado:
# Formato:  (44898, 7)
#                                                    title  \
# 40112  Ukraine airport says tightened security after ...
# 36028  Exclusive: Detained Saudi billionaire al-Sanea...
# 13303  LIBERTARIAN Gary Johnson ENDORSES Black Lives ...
# 32102  UAW chief says Clinton told him she would rene...
# 12870  FBI DATA Shows Black-On-Black Murders Off The ...
#
#                                                     text       subject  \
# 40112  KIEV (Reuters) - Ukraine s Odessa airport said...     worldnews
# 36028  DUBAI (Reuters) - A detained Saudi billionaire...     worldnews
# 13303  Johnson calls Obama s manufactured race war/wa...      politics
# 32102  (Reuters) - United Auto Workers President Denn...  politicsNews
# 12870  America has never seen two people living in th...      politics
#
#                      date  label  \
# 40112   October 24, 2017       1
# 36028  December 11, 2017       1
# 13303         Aug 8, 2016      0
# 32102      July 26, 2016       1
# 12870         Oct 1, 2016      0
#
#                                                full_text  \
# 40112  Ukraine airport says tightened security after ...
# 36028  Exclusive: Detained Saudi billionaire al-Sanea...
# 13303  LIBERTARIAN Gary Johnson ENDORSES Black Lives ...
# 32102  UAW chief says Clinton told him she would rene...
# 12870  FBI DATA Shows Black-On-Black Murders Off The ...
#
#                                          full_text_clean
# 40112  ukraine airport say tightened security cyber a...
# 36028  exclusive detained saudi billionaire alsanea s...
# 13303  libertarian gary johnson endorses black life m...
# 32102  uaw chief say clinton told would renegotiate n...
# 12870  fbi data show blackonblack murder chart obama ...

# %% [markdown]
# # **Armazenamento do dataset concatenado processado**

# %%
import pandas as pd

# Salva o dataset processado em um arquivo CSV. É necessário que a pasta processed exista dentro de data.
if not os.path.exists(os.path.join(BASE_DIR, "data", "processed")):
    os.makedirs(os.path.join(BASE_DIR, "data", "processed"), exist_ok=True)
processed_df.to_csv(os.path.join(BASE_DIR, "data", "processed", "processed_dataset.csv"), index=False)
